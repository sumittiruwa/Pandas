# %%
import numpy as np
import pandas as pd

# %%
dic = {
    "name":['harry', 'rohan', 'krihsna', 'subod'],
    "marks":[98,23,90,20],
    "city":['kathamandu','bhaktapur','lalitpur','kritipur'],
}

# %%
df = pd.DataFrame(dic)

# %%
df
# Out:
#       name  marks        city
# 0    harry     98  kathamandu
# 1    rohan     23   bhaktapur
# 2  krihsna     90    lalitpur
# 3    subod     20    kritipur

# %%
 d f.to_csv('friens.csv')
# Out:
#   Cell In[5], line 1
#     d f.to_csv('friens.csv')
#       ^
# SyntaxError: invalid syntax

# %%
df.to_csv('friens.csv')
